# %% [markdown]
# # AMMI Deep Natural Language Processing: Lab 1

# %% [markdown]
# ## 0. Introduction

# %% [markdown]
# In this tutorial we will train neural networks on the bAbI tasks using ParlAI framework.
# This tutorial can be run both in google colab or on your computer.
# The solutions will be added during the lab [here](https://fburl.com/ammi_dnlp_lab1).
#
# We will cover the following:
# 0. Introduction
#     - Introduction to ParlAI and installation
#     - Introduction to the bAbI tasks
# 1. Exploring the data:
#     - Compute some statistics (number of examples in train, valid, test, size of examples...)
#     - Look at some examples
# 2. Choose the appropriate metrics
# 3. Baselines
#     - Ranom baseline
#     - Majority class baseline
#     - Information retrieval baseline
# 4. More elaborate models
#    - Generative model: Seq2Seq
#    - Ranking model: Memory Network
# 5. To go further
#     - Additional ideas to try if you want to dig deeper
#
# ### ParlAI
# [ParlAI](https://github.com/facebookresearch/ParlAI/blob/master/README.md) (pronounced “par-lay”) is a framework for dialogue AI research, implemented in Python.
#
# Its goal is to provide researchers:
#
# * a unified framework for sharing, training and testing dialogue models
# * many popular datasets available all in one place -- from open-domain chitchat to visual question answering.
# * a wide set of reference models -- from retrieval baselines to Transformers.
# * seamless integration of Amazon Mechanical Turk for data collection and human evaluation
# * integration with Facebook Messenger to connect agents with humans in a chat interface
#
# Documentation can be found [here](http://www.parl.ai/static/docs/), some of this tutorial is inspired from the ParlAI documentation so feel free to go back and forth between the notebook and the documentation.
#
#
# ### Setup the notebook
# If using google colab, make sure to use TPU runtime by going to ***Runtime > Change runtime type > Hardware accelerator: TPU > Save***

# %% [markdown]
# ### Install ParlAI
#
# Start by installing ParlAI from github. The ParlAI folder will be located in the home directory at `~/ParlAI/`.
# *Note: In a jupyter notebook, you can run arbitrary bash commands by prefixing them with a question mark, example: `!echo "Hello World"`*

# %%
# !git clone https://github.com/facebookresearch/ParlAI.git ~/ParlAI
# !cd ~/ParlAI && git checkout 6bd0e58692b3fd3a13b5f654944525ac1b7cd8e3
# !cd ~/ParlAI; python setup.py develop
# Out:
# Cloning into '/root/ParlAI'...
# remote: Enumerating objects: 39179, done.
# remote: Counting objects: 100% (433/433), done.
# remote: Compressing objects: 100% (320/320), done.
# remote: Total 39179 (delta 177), reused 314 (delta 107), pack-reused 38746
# Receiving objects: 100% (39179/39179), 64.98 MiB | 31.57 MiB/s, done.
# Resolving deltas: 100% (27909/27909), done.
# Note: checking out '6bd0e58692b3fd3a13b5f654944525ac1b7cd8e3'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 6bd0e586 light paper link on webpage! (#1536)
# running develop
# running egg_info
# creating parlai.egg-info
# writing parlai.egg-info/PKG-INFO
# writing dependency_links to parlai.egg-info/dependency_links.txt
# writing requirements to parlai.egg-info/requires.txt
# writing top-level names to parlai.egg-info/top_level.txt
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# adding license file 'LICENSE' (matched pattern 'LICEN[CS]E*')
# reading manifest template 'MANIFEST.in'
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.7/dist-packages/parlai.egg-link (link to .)
# Adding parlai 0.1.0 to easy-install.pth file
#
# Installed /root/ParlAI
# Processing dependencies for parlai==0.1.0
# Searching for websocket_server
# Reading https://pypi.org/simple/websocket_server/
# Downloading https://files.pythonhosted.org/packages/74/64/e86581ee7775a2e08aca530b41e1a1e3ee6b320233b1eff301dcb86d1636/websocket_server-0.4.tar.gz#sha256=91cd4b565d1e1b00ef107abcb2840a8090868b19543f3b38e1962d5f975d0c04
# Best match: websocket-server 0.4
# Processing websocket_server-0.4.tar.gz
# Writing /tmp/easy_install-7ht_acre/websocket_server-0.4/setup.cfg
# Running websocket_server-0.4/setup.py -q bdist_egg --dist-dir /tmp/easy_install-7ht_acre/websocket_server-0.4/egg-dist-tmp-sd3u2f46
# zip_safe flag not set; analyzing archive contents...
# Moving websocket_server-0.4-py3.7.egg to /usr/local/lib/python3.7/dist-packages
# Adding websocket-server 0.4 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/websocket_server-0.4-py3.7.egg
# Searching for websocket
# Reading https://pypi.org/simple/websocket/
# Downloading https://files.pythonhosted.org/packages/f2/6d/a60d620ea575c885510c574909d2e3ed62129b121fa2df00ca1c81024c87/websocket-0.2.1.tar.gz#sha256=42b506fae914ac5ed654e23ba9742e6a342b1a1c3eb92632b6166c65256469a4
# Best match: websocket 0.2.1
# Processing websocket-0.2.1.tar.gz
# Writing /tmp/easy_install-5t0p4fb5/websocket-0.2.1/setup.cfg
# Running websocket-0.2.1/setup.py -q bdist_egg --dist-dir /tmp/easy_install-5t0p4fb5/websocket-0.2.1/egg-dist-tmp-poefz069
#   File "build/bdist.linux-x86_64/egg/websocket/server.py", line 57
#     except IOError, ex:
#                   ^
# SyntaxError: invalid syntax
#
#   File "build/bdist.linux-x86_64/egg/websocket/policyserver.py", line 21
#     print 'Accepted connection from %s:%s' % address
#                                          ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('Accepted connection from %s:%s' % address)?
#
# creating /usr/local/lib/python3.7/dist-packages/websocket-0.2.1-py3.7.egg
# Extracting websocket-0.2.1-py3.7.egg to /usr/local/lib/python3.7/dist-packages
#   File "/usr/local/lib/python3.7/dist-packages/websocket-0.2.1-py3.7.egg/websocket/policyserver.py", line 21
#     print 'Accepted connection from %s:%s' % address
#                                          ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print('Accepted connection from %s:%s' % address)?
#
#   File "/usr/local/lib/python3.7/dist-packages/websocket-0.2.1-py3.7.egg/websocket/server.py", line 57
#     except IOError, ex:
#                   ^
# SyntaxError: invalid syntax
#
# Adding websocket 0.2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/websocket-0.2.1-py3.7.egg
# Searching for sphinx_rtd_theme
# Reading https://pypi.org/simple/sphinx_rtd_theme/
# Downloading https://files.pythonhosted.org/packages/ac/24/2475e8f83519b54b2148d4a56eb1111f9cec630d088c3ffc214492c12107/sphinx_rtd_theme-0.5.2-py2.py3-none-any.whl#sha256=4a05bdbe8b1446d77a01e20a23ebc6777c74f43237035e76be89699308987d6f
# Best match: sphinx-rtd-theme 0.5.2
# Processing sphinx_rtd_theme-0.5.2-py2.py3-none-any.whl
# Installing sphinx_rtd_theme-0.5.2-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding sphinx-rtd-theme 0.5.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/sphinx_rtd_theme-0.5.2-py3.7.egg
# Searching for sh
# Reading https://pypi.org/simple/sh/
# Downloading https://files.pythonhosted.org/packages/7a/c3/0836b7b975d09428d90f926dc1f86e2d76d721cf79bd6659838761c35f85/sh-1.14.2-py2.py3-none-any.whl#sha256=4921ac9c1a77ec8084bdfaf152fe14138e2b3557cc740002c1a97076321fce8a
# Best match: sh 1.14.2
# Processing sh-1.14.2-py2.py3-none-any.whl
# Installing sh-1.14.2-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding sh 1.14.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/sh-1.14.2-py3.7.egg
# Searching for gitpython
# Reading https://pypi.org/simple/gitpython/
# Downloading https://files.pythonhosted.org/packages/27/da/6f6224fdfc47dab57881fe20c0d1bc3122be290198ba0bf26a953a045d92/GitPython-3.1.17-py3-none-any.whl#sha256=29fe82050709760081f588dd50ce83504feddbebdc4da6956d02351552b1c135
# Best match: GitPython 3.1.17
# Processing GitPython-3.1.17-py3-none-any.whl
# Installing GitPython-3.1.17-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding GitPython 3.1.17 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/GitPython-3.1.17-py3.7.egg
# Searching for flake8
# Reading https://pypi.org/simple/flake8/
# Downloading https://files.pythonhosted.org/packages/fc/80/35a0716e5d5101e643404dabd20f07f5528a21f3ef4032d31a49c913237b/flake8-3.9.2-py2.py3-none-any.whl#sha256=bf8fd333346d844f616e8d47905ef3a3384edae6b4e9beb0c5101e25e3110907
# Best match: flake8 3.9.2
# Processing flake8-3.9.2-py2.py3-none-any.whl
# Installing flake8-3.9.2-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding flake8 3.9.2 to easy-install.pth file
# Installing flake8 script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/flake8-3.9.2-py3.7.egg
# Searching for botocore
# Reading https://pypi.org/simple/botocore/
# Downloading https://files.pythonhosted.org/packages/bc/22/72c81d754bbcb128cba2ad88670c3c320e4594e6ddd8cca6512c3967108c/botocore-1.20.84-py2.py3-none-any.whl#sha256=75e1397b80aa8757a26636b949eebd20b3cf67e8f1ed80dc01170907e06ea45d
# Best match: botocore 1.20.84
# Processing botocore-1.20.84-py2.py3-none-any.whl
# Installing botocore-1.20.84-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding botocore 1.20.84 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/botocore-1.20.84-py3.7.egg
# Searching for boto3
# Reading https://pypi.org/simple/boto3/
# Downloading https://files.pythonhosted.org/packages/11/20/4294e37c3c6936c905f1e9da958c776d7fee54a4512bdb7706d69c8720e6/boto3-1.17.84-py2.py3-none-any.whl#sha256=1d24c6d1f5db4b52bb29f1dfe13fd3e9d95d9fa4634b0638a096f5a884173cde
# Best match: boto3 1.17.84
# Processing boto3-1.17.84-py2.py3-none-any.whl
# Installing boto3-1.17.84-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding boto3 1.17.84 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/boto3-1.17.84-py3.7.egg
# Searching for gevent
# Reading https://pypi.org/simple/gevent/
# Downloading https://files.pythonhosted.org/packages/3e/85/df3d1fd2b60a87455475f93012861b76a411d27ba4a0859939adbe2c9dc3/gevent-21.1.2-cp37-cp37m-manylinux2010_x86_64.whl#sha256=ac98570649d9c276e39501a1d1cbf6c652b78f57a0eb1445c5ff25ff80336b63
# Best match: gevent 21.1.2
# Processing gevent-21.1.2-cp37-cp37m-manylinux2010_x86_64.whl
# Installing gevent-21.1.2-cp37-cp37m-manylinux2010_x86_64.whl to /usr/local/lib/python3.7/dist-packages
# Adding gevent 21.1.2 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/gevent-21.1.2-py3.7-linux-x86_64.egg
# Searching for docutils<0.17
# Reading https://pypi.org/simple/docutils/
# Downloading https://files.pythonhosted.org/packages/81/44/8a15e45ffa96e6cf82956dd8d7af9e666357e16b0d93b253903475ee947f/docutils-0.16-py2.py3-none-any.whl#sha256=0c5b78adfbf7762415433f5515cd5c9e762339e23369dbe8000d84a4bf4ab3af
# Best match: docutils 0.16
# Processing docutils-0.16-py2.py3-none-any.whl
# Installing docutils-0.16-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding docutils 0.16 to easy-install.pth file
# Installing rst2s5.py script to /usr/local/bin
# Installing rst2odt.py script to /usr/local/bin
# Installing rst2html5.py script to /usr/local/bin
# Installing rst2man.py script to /usr/local/bin
# Installing rst2pseudoxml.py script to /usr/local/bin
# Installing rst2latex.py script to /usr/local/bin
# Installing rst2html.py script to /usr/local/bin
# Installing rst2xetex.py script to /usr/local/bin
# Installing rst2xml.py script to /usr/local/bin
# Installing rst2odt_prepstyles.py script to /usr/local/bin
# Installing rst2html4.py script to /usr/local/bin
# Installing rstpep2html.py script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/docutils-0.16-py3.7.egg
# Searching for gitdb<5,>=4.0.1
# Reading https://pypi.org/simple/gitdb/
# Downloading https://files.pythonhosted.org/packages/ea/e8/f414d1a4f0bbc668ed441f74f44c116d9816833a48bf81d22b697090dba8/gitdb-4.0.7-py3-none-any.whl#sha256=6c4cc71933456991da20917998acbe6cf4fb41eeaab7d6d67fbc05ecd4c865b0
# Best match: gitdb 4.0.7
# Processing gitdb-4.0.7-py3-none-any.whl
# Installing gitdb-4.0.7-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding gitdb 4.0.7 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/gitdb-4.0.7-py3.7.egg
# Searching for pyflakes<2.4.0,>=2.3.0
# Reading https://pypi.org/simple/pyflakes/
# Downloading https://files.pythonhosted.org/packages/6c/11/2a745612f1d3cbbd9c69ba14b1b43a35a2f5c3c81cd0124508c52c64307f/pyflakes-2.3.1-py2.py3-none-any.whl#sha256=7893783d01b8a89811dd72d7dfd4d84ff098e5eed95cfa8905b22bbffe52efc3
# Best match: pyflakes 2.3.1
# Processing pyflakes-2.3.1-py2.py3-none-any.whl
# Installing pyflakes-2.3.1-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding pyflakes 2.3.1 to easy-install.pth file
# Installing pyflakes script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/pyflakes-2.3.1-py3.7.egg
# Searching for pycodestyle<2.8.0,>=2.7.0
# Reading https://pypi.org/simple/pycodestyle/
# Downloading https://files.pythonhosted.org/packages/de/cc/227251b1471f129bc35e966bb0fceb005969023926d744139642d847b7ae/pycodestyle-2.7.0-py2.py3-none-any.whl#sha256=514f76d918fcc0b55c6680472f0a37970994e07bbb80725808c17089be302068
# Best match: pycodestyle 2.7.0
# Processing pycodestyle-2.7.0-py2.py3-none-any.whl
# Installing pycodestyle-2.7.0-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding pycodestyle 2.7.0 to easy-install.pth file
# Installing pycodestyle script to /usr/local/bin
#
# Installed /usr/local/lib/python3.7/dist-packages/pycodestyle-2.7.0-py3.7.egg
# Searching for mccabe<0.7.0,>=0.6.0
# Reading https://pypi.org/simple/mccabe/
# Downloading https://files.pythonhosted.org/packages/87/89/479dc97e18549e21354893e4ee4ef36db1d237534982482c3681ee6e7b57/mccabe-0.6.1-py2.py3-none-any.whl#sha256=ab8a6258860da4b6677da4bd2fe5dc2c659cff31b3ee4f7f5d64e79735b80d42
# Best match: mccabe 0.6.1
# Processing mccabe-0.6.1-py2.py3-none-any.whl
# Installing mccabe-0.6.1-py2.py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# Adding mccabe 0.6.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.7/dist-packages/mccabe-0.6.1-py3.7.egg
# error: urllib3 1.24.3 is installed but urllib3<1.27,>=1.25.4 is required by {'botocore'}

# %% [markdown]
# Most of the scripts that we will use in ParlAI are located in the `~/ParlAI/examples` directory.
# Let's have a first glance at the scripts available, we will come back to them later:

# %%
# !ls ~/ParlAI/examples/
# Out:
# base_train.py	       eval_model.py		 remote.py
# build_dict.py	       extract_image_feature.py  seq2seq_train_babi.py
# build_pytorch_data.py  interactive.py		 train_model.py
# display_data.py        profile_train.py
# display_model.py       README.md

# %% [markdown]
# ### The bAbI tasks
# Many datasets and tasks are included in ParlAI, we will focus on the bAbI tasks.
# The bAbI tasks are 20 synthetic tasks that each test a unique aspect of text and reasoning, and hence test different capabilities of learning models from [Weston et al. ‘16](http://arxiv.org/abs/1502.05698).
#
# ---
# **Question 0.**
# Open the bAbI [paper](https://arxiv.org/pdf/1502.05698.pdf) and read the abstract  and section: *"3 The Tasks"* (until paragraph **Two or Three Supporting Facts**,  included).
# - **0.a.** Explain in your own words the motivations behind these tasks (in 2-3 sentences).
#
# *ANSWER HERE*
#
#     -The main motivation behind these tasks is to be able evaluate the performance of dialog systems on reasoning
#     and natural langauge so as to help researchers to easily identify and rectify these systems incase of failure.
#
# These tasks can be downloaded and used directly from ParlAI.
# We will focus on tasks 1, 2 and 3, see examples below:
#
#
# **Task 1: Single Supporting Fact**
# Mary went to the bathroom.
# John moved to the hallway.
# Mary travelled to the office.
# Where is Mary?
# **Answer: office**
#
#
# **Task 2: Two Supporting Facts**
# John is in the playground.
# John picked up the football.
# Bob went to the kitchen.
# Where is the football?
# **Answer: playground**
#
#
# **Task 3: Three Supporting Facts **
# John picked up the apple.
# John went to the office.
# John went to the kitchen.
# John dropped the apple.
# Where was the apple before the kitchen?
# **Answer: office**

# %% [markdown]
# ## 1. Exploring the data

# %% [markdown]
# First we need to download the data, we will use the `build_dict.py` as a dummy task to download the data.

# %%
# Download the data silently
# !python ~/ParlAI/examples/build_dict.py --task babi:task1k:1 --dict-file /tmp/babi1.dict
# Print a few examples
# !head -n 30 ~/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt
# Out:
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: train ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task1k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: None ]
# [  init_model: None ]
# [  model: None ]
# [  model_file: None ]
# [ PytorchData Arguments: ]
# [  batch_length_range: 5 ]
# [  batch_sort_cache_type: pop ]
# [  batch_sort_field: text ]
# [  numworkers: 4 ]
# [  pytorch_context_length: -1 ]
# [  pytorch_datapath: None ]
# [  pytorch_include_labels: True ]
# [  pytorch_preprocess: False ]
# [  pytorch_teacher_batch_sort: False ]
# [  pytorch_teacher_dataset: None ]
# [  pytorch_teacher_task: None ]
# [  shuffle: False ]
# [ Dictionary Loop Arguments: ]
# [  dict_include_test: False ]
# [  dict_include_valid: False ]
# [  dict_maxexs: -1 ]
# [  log_every_n_secs: 2 ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: /tmp/babi1.dict ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [creating task(s): babi:task1k:1]
# [building data: /root/ParlAI/data/bAbI]
# [ downloading: http://parl.ai/downloads/babi/babi.tar.gz to /root/ParlAI/data/bAbI/babi.tar.gz ]
# Downloading babi.tar.gz: 100% 19.2M/19.2M [00:01<00:00, 11.5MB/s]
# unpacking babi.tar.gz
# [ running dictionary over data.. ]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-nosf/qa1_train.txt]
# Building dictionary:   0% 0.00/900 [00:00<?, ?ex/s][loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-nosf/qa1_train.txt]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-nosf/qa1_train.txt]
# Building dictionary: 100% 900/900 [00:00<00:00, 24.6kex/s]
# Dictionary: saving dictionary to /tmp/babi1.dict
# [ dictionary built with 26 tokens in 0s ]
# 1 Mary moved to the bathroom.
# 2 John went to the hallway.
# 3 Where is Mary? 	bathroom
# 4 Daniel went back to the hallway.
# 5 Sandra moved to the garden.
# 6 Where is Daniel? 	hallway
# 7 John moved to the office.
# 8 Sandra journeyed to the bathroom.
# 9 Where is Daniel? 	hallway
# 10 Mary moved to the hallway.
# 11 Daniel travelled to the office.
# 12 Where is Daniel? 	office
# 13 John went back to the garden.
# 14 John moved to the bedroom.
# 15 Where is Sandra? 	bathroom
# 1 Mary went to the bedroom.
# 2 John journeyed to the bathroom.
# 3 Where is John? 	bathroom
# 4 Sandra journeyed to the hallway.
# 5 John journeyed to the garden.
# 6 Where is Mary? 	bedroom
# 7 John journeyed to the bathroom.
# 8 Sandra journeyed to the garden.
# 9 Where is John? 	bathroom
# 10 Sandra went back to the bedroom.
# 11 Daniel travelled to the bathroom.
# 12 Where is John? 	bathroom
# 13 John went to the office.
# 14 Mary moved to the office.
# 15 Where is Sandra? 	bedroom

# %% [markdown]
# The bAbI tasks were downloaded in `~/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-nosf/`
#
# In bAbI the data is organised as follows:
# - **Dialog turn**: A dialog turn is a single utterance / statement. Each line in the file corresponds to one dialog turn.
#   Example: *"John went to the office."*
# - **Sample (question)**: Every few dialog turns, a question can be asked that the model has to answer, this consitute a sample.  The question is followed by its ground truth answer, separated by a tab.
#   Example: *"Where is John? `<tab>` bathroom"*
# - **Episode**: a sequence of ordered coherent dialog turns that are related to each other form an episode. Each new episode is independant of the others. Each line starts with the dialog turn number in the current episode.
#
#
# ---
# **Question 1.**
# - **1.a.** Look at the training file of task 1 (`~/ParlAI/data/bAbI/tasks_1-20_v1-2/en/qa1_train.txt`) and compute the following information:
#   - Number of episodes
#   - Number of  samples (questions)
#   - Number of dialog turns per episode
#   - How many different answers are there in the train set? How many times does each appear? (*hint: Use a python [counter](https://docs.python.org/3/library/collections.html#collections.Counter)*)
#   - How many unique words appear in the training set? How many time does each appear? (*hint: Use the Counter `most_common()` method*)
#
# *Print the answer in the following code cell*
#
#   ---

# %%
# SOLUTION
from collections import Counter
task_1_train_path = '/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt'
i = 0
no_episodes = 0
no_questions = 0
no_total_dialog_turns = 0
possible_answers = Counter()
possible_answers_dict = {}
vocabulary = Counter()
with open(task_1_train_path, 'r') as f:
    for line in f:
        # Each line starts with an integer giving the dialog turn in the current episode.
        # Each episode contains dialog turns with questions (with the answer next to it separated by a tab)
        line = line.strip('\n')
        dialog_turn = int(line.split(' ')[0])
        if dialog_turn == 1:
            no_episodes += 1
        # Remove the dialog turn number
        line = ' '.join(line.split(' ')[1:])
        fields = line.split('\t')
        if len(fields) > 1:
            no_questions += 1
            possible_answers.update([fields[1]])
        vocabulary.update(fields[0].split(' '))
        no_total_dialog_turns += 1
print(f'No of episodes: {no_episodes}')
print(f'No of questions: {no_questions}')
print(f'No of dialog turns per episode: {no_total_dialog_turns/no_episodes}')
print(f'Possible answers: {possible_answers} ({len(possible_answers)})')
print(f'Accuracy of a random model: {1/len(possible_answers):.4f}')
print(f'Vocabulary size: {len(vocabulary)}')
print(f'Most common words: {vocabulary.most_common()}')
# Out:
# Number of episodes: 1800
# Number of questions: 9000
# Number of dialog turns per episode: 15.0
# Possible answers: Counter({'bathroom': 1564, 'hallway': 1517, 'garden': 1508, 'bedroom': 1473, 'kitchen': 1471, 'office': 1467}) (6)
# Accuracy of a random model: 0.1667
# Vocabulary size: 24
# Most common words: [('to', 18000), ('the', 18000), ('Where', 9000), ('is', 9000), ('', 9000), ('went', 7225), ('Mary', 4535), ('Sandra', 4502), ('John', 4484), ('Daniel', 4479), ('journeyed', 3620), ('travelled', 3582), ('back', 3581), ('moved', 3573), ('bathroom.', 3070), ('hallway.', 3045), ('garden.', 2982), ('kitchen.', 2981), ('office.', 2963), ('bedroom.', 2959), ('John?', 2299), ('Mary?', 2265), ('Sandra?', 2244), ('Daniel?', 2192)]

# %% [markdown]
# - **2.b.** Use the appropriate script from the `~/ParlAI/examples/` to take a quick look at examples of the first bAbI task.
# Does the number of episodes and examples fit what you computed before? (*hint: you can use the argument `--task babi:task1k:1` to select the first babi task*)

# %%
# FILL THIS CELL
# !python ~/ParlAI/examples/display_data.py --task babi:task10k:1
# Out:
# [ optional arguments: ]
# [  display_ignore_fields: agent_reply ]
# [  max_display_len: 1000 ]
# [  num_examples: 10 ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: train:stream ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task10k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: None ]
# [  init_model: None ]
# [  model: None ]
# [  model_file: None ]
# [ PytorchData Arguments: ]
# [  batch_length_range: 5 ]
# [  batch_sort_cache_type: pop ]
# [  batch_sort_field: text ]
# [  numworkers: 4 ]
# [  pytorch_context_length: -1 ]
# [  pytorch_datapath: None ]
# [  pytorch_include_labels: True ]
# [  pytorch_preprocess: False ]
# [  pytorch_teacher_batch_sort: False ]
# [  pytorch_teacher_dataset: None ]
# [  pytorch_teacher_task: None ]
# [  shuffle: False ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# [babi:task10k:1]: Mary moved to the bathroom.
# John went to the hallway.
# Where is Mary?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task10k:1]: Daniel went back to the hallway.
# Sandra moved to the garden.
# Where is Daniel?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task10k:1]: John moved to the office.
# Sandra journeyed to the bathroom.
# Where is Daniel?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: hallway]
# ~~
# [babi:task10k:1]: Mary moved to the hallway.
# Daniel travelled to the office.
# Where is Daniel?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: office]
# ~~
# [babi:task10k:1]: John went back to the garden.
# John moved to the bedroom.
# Where is Sandra?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: bathroom]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [babi:task10k:1]: Mary went to the bedroom.
# John journeyed to the bathroom.
# Where is John?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task10k:1]: Sandra journeyed to the hallway.
# John journeyed to the garden.
# Where is Mary?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: bedroom]
# ~~
# [babi:task10k:1]: John journeyed to the bathroom.
# Sandra journeyed to the garden.
# Where is John?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task10k:1]: Sandra went back to the bedroom.
# Daniel travelled to the bathroom.
# Where is John?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: bathroom]
# ~~
# [babi:task10k:1]: John went to the office.
# Mary moved to the office.
# Where is Sandra?
# [label_candidates: bathroom|bedroom|office|hallway|kitchen|...and 1 more]
# [labels: bedroom]
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [ loaded 1800 episodes with a total of 9000 examples ]

# %% [markdown]
#     -Yes it fits since we have  loaded 1800 episodes with a total of 9000 examples

# %% [markdown]
# ## 2. Metrics

# %% [markdown]
# The bAbI task 1 expects single word answers among a small set of possible answers.
#
#
# ---
# **Question 2**
# - **2.a.** Which metrics do you think are appropriate for evaluating a model on this task?
# -  **2.b.**  What are their respective strengths?
# -  **2.c.** When do they fail? (find specific examples)
#
#
# *ANSWER HERE*
#
#
#
#
# ---

# %% [markdown]
#     2a)
#     -Accuracy
#
# 2b)strengths :
#
#     -It is   easier to compute
#     -It is reproduceable
# 2c) When do they fail
#
#     -Incase a question has multiple/related responses,Accuracy my not work  well since there have to be a perfect,
#     exact, match of the response

# %% [markdown]
# ## 3. Baseline

# %% [markdown]
# We now have a clearer idea of the data distribution and the metrics that we can use.
# The next step is to start solving the tasks with a simple baseline. This will allow us to compare more elaborate models agains this baseline.
# Here are a few classical baselines:
# - **Random model**: The model answers randomly among the set of possible answers for each question
# -  **Majority class**: The model always answers with the most frequent answer in the training set (majority class)
#
# We are going to reimplement these own baselines.
# Implementing a new model in ParlAI is detailed in the [tutorial](http://parl.ai/static/docs/seq2seq_tutorial.html) but for our simple baselines, we will only need to inherit the [Agent](https://github.com/facebookresearch/ParlAI/blob/6d246842d3f4e941dd3806f3d9fa62f607d48f59/parlai/core/agents.py#L50) class and override the `act()` method.
#
# ---
# **Question 3**
# - **3.a.** What would be the accuracy of a model that choses a random answer among the set of possible answers for each question?
#
# *ANSWER HERE*
#
#     Taking n questions and k set of possible answers, the accuracy of a random model is computed as follows:
#
#      acc = (n/k)*100
#
#
# ---
#
# *Note: the `%%writefile` magic command in jupyter writes the content of the cell to a file at the given path.*

# %%
# !mkdir -p ~/ParlAI/parlai/agents/baseline/
# !touch ~/ParlAI/parlai/agents/baseline/random.py
# !touch ~/ParlAI/parlai/agents/baseline/majorityclass.py

# %% [markdown]
# - **3.b.**  Design a baseline that answers a random word in the set of possible answer (run it multiple time to observe variance in results).

# %%
# SOLUTION
# %%writefile ~/ParlAI/parlai/agents/baseline/random.py
import random
from parlai.core.torch_agent import Agent
class RandomAgent(Agent):
  
    def act(self):
        if 'label_candidates' not in self.observation:
            return
        candidates = list(self.observation['label_candidates'])
        reply = {'text': candidates[random.randrange(len(candidates))]}
        return reply
# Out:
# Overwriting /root/ParlAI/parlai/agents/baseline/random.py

# %%
# !python ~/ParlAI/examples/eval_model.py -t babi:task10k:1 -m baseline/random | grep accuracy -A 1
# Out:
# {'exs': 1000, 'accuracy': 0.165, 'f1': 0.165, 'bleu': 1.65e-10}

# %%
# !python ~/ParlAI/examples/display_model.py -t babi:task10k:1 -m baseline/random -n 10
# Out:
# [ optional arguments: ]
# [  display_ignore_fields:  ]
# [  num_examples: 10 ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: valid ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task10k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: None ]
# [  init_model: None ]
# [  model: baseline/random ]
# [  model_file: None ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_valid.txt]
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: bathroom]
#    bathroom
# ~~
# [babi:task10k:1]: Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: bathroom]
#    office
# ~~
# [babi:task10k:1]: John went to the garden.
# John travelled to the office.
# Where is Sandra?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: bathroom]
#    office
# ~~
# [babi:task10k:1]: Daniel journeyed to the bedroom.
# Daniel travelled to the hallway.
# Where is John?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: office]
#    bathroom
# ~~
# [babi:task10k:1]: John went to the bedroom.
# John travelled to the office.
# Where is Daniel?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: hallway]
#    bedroom
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: garden]
#    garden
# ~~
# [babi:task10k:1]: Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: office]
#    garden
# ~~
# [babi:task10k:1]: John went back to the hallway.
# John travelled to the office.
# Where is Sandra?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: office]
#    garden
# ~~
# [babi:task10k:1]: Sandra journeyed to the hallway.
# Daniel moved to the office.
# Where is John?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: office]
#    bathroom
# ~~
# [babi:task10k:1]: Mary went to the office.
# Sandra went to the office.
# Where is John?
# [label_candidates: office|garden|bedroom|hallway|kitchen|...and 1 more]
# [eval_labels: office]
#    office
# - - - - - - - - - - - - - - - - - - - - -
# ~~

# %% [markdown]
# - **3.c.**  Design a baseline that answers the most common answer every time (majority class baseline).

# %%
# SOLUTION
# %%writefile ~/ParlAI/parlai/agents/baseline/majorityclass.py
import random
from parlai.core.torch_agent import Agent

class MajorityclassAgent(Agent):
    def act(self):
        if 'label_candidates' not in self.observation:
            return
        reply = {'text': 'bathroom'}
        return reply
# Out:
# Overwriting /root/ParlAI/parlai/agents/baseline/majorityclass.py

# %%
# !python ~/ParlAI/examples/eval_model.py -t babi:task10k:1 -m baseline/majorityclass | grep accuracy -A 1
# Out:
# {'exs': 1000, 'accuracy': 0.169, 'f1': 0.169, 'bleu': 1.69e-10}

# %%
# !python ~/ParlAI/examples/display_model.py -t babi:task10k:1 -m baseline/majorityclass -n 10
# Out:
# [ optional arguments: ]
# [  display_ignore_fields:  ]
# [  num_examples: 10 ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: valid ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task10k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: None ]
# [  init_model: None ]
# [  model: baseline/majorityclass ]
# [  model_file: None ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_valid.txt]
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# [eval_labels: bathroom]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# [eval_labels: bathroom]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: John went to the garden.
# John travelled to the office.
# Where is Sandra?
# [eval_labels: bathroom]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: Daniel journeyed to the bedroom.
# Daniel travelled to the hallway.
# Where is John?
# [eval_labels: office]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: John went to the bedroom.
# John travelled to the office.
# Where is Daniel?
# [eval_labels: hallway]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# [eval_labels: garden]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# [eval_labels: office]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: John went back to the hallway.
# John travelled to the office.
# Where is Sandra?
# [eval_labels: office]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: Sandra journeyed to the hallway.
# Daniel moved to the office.
# Where is John?
# [eval_labels: office]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# ~~
# [babi:task10k:1]: Mary went to the office.
# Sandra went to the office.
# Where is John?
# [eval_labels: office]
# [label_candidates: kitchen|garden|hallway|bathroom|office|...and 1 more]
#    bathroom
# - - - - - - - - - - - - - - - - - - - - -
# ~~

# %% [markdown]
# ---
# - **3.d.**  In which cases would the majority class baseline be better than the random baseline?
#
# *ANSWER HERE*
#
#     When the  majority class has the most dorminant samples in the whole data
# ---

# %% [markdown]
# Another slightly more advanced baseline is implemented in ParlAI: the information retrieval baseline (`ir_baseline`)
#
# ---
# - **3.e.** Look at the [implementation](https://github.com/facebookresearch/ParlAI/blob/53ea58acf389bffc79c85c43bcdd848eecdcecb4/parlai/agents/ir_baseline/ir_baseline.py#L211) of the IR baseline and explain in a few lines how it works (*hint: look at the following methods `act()` `rank_candidates()`  `score_match()`*)
#
# *ANSWER HERE*
#
#     -This is an Information Retrieval baseline model that  ranks words based on their frequency whereby Most
#     frequent words  will score less
#
#     -Sentences are scored based on the words within it  and then ordered based on their scores
#
#     -At the end it returns the candidate with the highest score from the dialog history. OR returns
#     "I don't know" if no history found
#
#
# ---

# %% [markdown]
# - **3.f.** Use the IR baseline and compare its with one of your baselines (random and/or majority) on bAbI tasks 1, 2 and 3.
#     (*hint: you can use `!python ... -t babi:task1-k:{i+1}` syntax to substitute the task number in a bash command from jupyter*)

# %%
# SOLUTION
for i in range(3):
    print(f'~ Task {i+1} ~')
    print('Majority class baseline:')
    # !python ~/ParlAI/examples/eval_model.py -t babi:task10k:{i+1} -m baseline/majorityclass | grep accuracy
    print('IR baseline:')
    # !python ~/ParlAI/examples/eval_model.py -t babi:task10k:{i+1} -m ir_baseline | grep accuracy
# Out:
# ~ Task 1 ~
# Majority class baseline:
# {'exs': 1000, 'accuracy': 0.169, 'f1': 0.169, 'bleu': 1.69e-10}
# IR baseline:
# {'exs': 1000, 'accuracy': 0.465, 'f1': 0.465, 'hits@1': 0.465, 'hits@5': 0.961, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 4.65e-10}
# ~ Task 2 ~
# Majority class baseline:
# {'exs': 1000, 'accuracy': 0.17, 'f1': 0.17, 'bleu': 1.7e-10}
# IR baseline:
# {'exs': 1000, 'accuracy': 0.284, 'f1': 0.284, 'hits@1': 0.284, 'hits@5': 0.9, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 2.84e-10}
# ~ Task 3 ~
# Majority class baseline:
# {'exs': 1000, 'accuracy': 0.203, 'f1': 0.203, 'bleu': 2.03e-10}
# IR baseline:
# {'exs': 1000, 'accuracy': 0.132, 'f1': 0.132, 'hits@1': 0.132, 'hits@5': 0.836, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 1.32e-10}

# %% [markdown]
# ## 4. More elaborate models

# %% [markdown]
# We can now continue to more elaborate models and evaluate their performance in perspective to the baselines.
# We will use the `~/ParlAI/examples/train_model.py` script. Let's first get a glance at its arguments:

# %%
# !python ~/ParlAI/examples/train_model.py --help
# Out:
# usage: train_model.py [-h] [-v] [-t TASK]
#                       [-dt {train,train:stream,train:ordered,train:ordered:stream,train:stream:ordered,train:evalmode,train:evalmode:stream,train:evalmode:ordered,train:evalmode:ordered:stream,train:evalmode:stream:ordered,valid,valid:stream,test,test:stream}]
#                       [-nt NUMTHREADS] [-bs BATCHSIZE] [-dp DATAPATH] [-m MODEL] [-mf MODEL_FILE] [-im INIT_MODEL] [-et EVALTASK]
#                       [-eps NUM_EPOCHS] [-ttim MAX_TRAIN_TIME] [-vtim VALIDATION_EVERY_N_SECS] [-stim SAVE_EVERY_N_SECS]
#                       [-sval SAVE_AFTER_VALID] [-veps VALIDATION_EVERY_N_EPOCHS] [-vp VALIDATION_PATIENCE]
#                       [-vmt VALIDATION_METRIC] [-vmm {max,min}] [-pyt PYTORCH_TEACHER_TASK] [-pytd PYTORCH_TEACHER_DATASET]
#
# Train a model
#
# optional arguments:
#   -h, --help
#         show this help message and exit
#
# Main ParlAI Arguments:
#   -v, --show-advanced-args
#         Show hidden command line options (advanced users only) (default: False)
#   -t, --task TASK
#         ParlAI task(s), e.g. "babi:Task1" or "babi,cbt" (default: None)
#   -dt, --datatype {train,train:stream,train:ordered,train:ordered:stream,train:stream:ordered,train:evalmode,train:evalmode:stream,train:evalmode:ordered,train:evalmode:ordered:stream,train:evalmode:stream:ordered,valid,valid:stream,test,test:stream}
#         choose from: train, train:ordered, valid, test. to stream data add ":stream" to any option (e.g., train:stream). by
#         default: train is random with replacement, valid is ordered, test is ordered. (default: train)
#   -nt, --numthreads NUMTHREADS
#         number of threads. Used for hogwild if batchsize is 1, else for number of threads in threadpool loading, (default: 1)
#   -bs, --batchsize BATCHSIZE
#         batch size for minibatch training schemes (default: 1)
#   -dp, --datapath DATAPATH
#         path to datasets, defaults to {parlai_dir}/data (default: /root/ParlAI/data)
#
# ParlAI Model Arguments:
#   -m, --model MODEL
#         the model class name. can match parlai/agents/<model> for agents in that directory, or can provide a fully specified
#         module for `from X import Y` via `-m X:Y` (e.g. `-m parlai.agents.seq2seq.seq2seq:Seq2SeqAgent`) (default: None)
#   -mf, --model-file MODEL_FILE
#         model file name for loading and saving models (default: None)
#   -im, --init-model INIT_MODEL
#         load model weights and dict from this file (default: None)
#
# Training Loop Arguments:
#   -et, --evaltask EVALTASK
#         task to use for valid/test (defaults to the one used for training if not set) (default: None)
#   -eps, --num-epochs NUM_EPOCHS
#   -ttim, --max-train-time MAX_TRAIN_TIME
#   -vtim, --validation-every-n-secs VALIDATION_EVERY_N_SECS
#         Validate every n seconds. Saves model to model_file (if set) whenever best val metric is found (default: -1)
#   -stim, --save-every-n-secs SAVE_EVERY_N_SECS
#         Saves the model to model_file.checkpoint after every n seconds (default -1, never). (default: -1)
#   -sval, --save-after-valid SAVE_AFTER_VALID
#         Saves the model to model_file.checkpoint after every validation (default False).
#   -veps, --validation-every-n-epochs VALIDATION_EVERY_N_EPOCHS
#         Validate every n epochs. Saves model to model_file (if set) whenever best val metric is found (default: -1)
#   -vp, --validation-patience VALIDATION_PATIENCE
#         number of iterations of validation where result does not improve before we stop training (default: 10)
#   -vmt, --validation-metric VALIDATION_METRIC
#         key into report table for selecting best validation (default: accuracy)
#   -vmm, --validation-metric-mode {max,min}
#         how to optimize validation metric (max or min) (default: None)
#
# PytorchData Arguments:
#   -pyt, --pytorch-teacher-task PYTORCH_TEACHER_TASK
#         Use the PytorchDataTeacher for multiprocessed data loading with a standard ParlAI task, e.g. "babi:Task1k" (default: None)
#   -pytd, --pytorch-teacher-dataset PYTORCH_TEACHER_DATASET
#         Use the PytorchDataTeacher for multiprocessed data loading with a pytorch Dataset, e.g. "vqa_1" or "flickr30k" (default:
#         None)

# %% [markdown]
# We can train two types of models:
# - **Generative models**: The model generates an answer from its vocabulary.
# - **Ranking models**: The model is given a list of possible answers and has to choose the correct answer. This is much easier for the model since the list of possible answers is often way smaller than the size of the vocabulary

# %% [markdown]
# ### Generative model: seq2seq with attention
#
# The generative model we are going to train is a sequence to sequence model with attention based on [Sustskever et al. 2014](https://arxiv.org/abs/1409.3215) and [Bahdanau et al. 2014](https://arxiv.org/abs/1409.0473).
#
# - **4.a.** Briefly explain how attention works in sequence to sequence neural networks.
# - **4.b.** Do you think attention is useful for the babi tasks? How would you verify it experimentally?
#
# *ANSWER HERE*
#
# ---
#     4.a we take input from each word of the encoder – and assign some weights  depending on the importance of that
#     word in the context of the whole sentence which is passed to the decoder
#     -decoder output is used with all output vectors from encoder to compute the attention score.
#     -we apply a Softmax function over the attention score to get the distribution
#     -Finally we compute the translated word.
#
#     4b. I think it is useful incase some tasks have long dialog turns and we need to maintain
#     long term dependancies between them
#
#
#
# - **4.c.** Train a seq2seq on bAbI task 1 (10k) and compare its results to the baselines.
#    (*hint: for faster training use the following arguments `--batchsize 32 --numthreads 1 --num-epochs 5 --hiddensize 64 --embeddingsize 64 --numlayers 1 --decoder shared`)

# %%
# FILL THIS CELL
# !python ~/ParlAI/examples/train_model.py --task babi:task10k:1 --model seq2seq  --model-file /tmp/babi_s2s --batchsize 32 --numthreads 1 --num-epochs 5 --hiddensize 64 --embeddingsize 64 --numlayers 1 --decoder shared
# Out:
# [ Main ParlAI Arguments: ]
# [  batchsize: 32 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: train ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task10k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: seq2seq ]
# [  model_file: /tmp/babi_s2s ]
# [ Training Loop Arguments: ]
# [  dict_build_first: True ]
# [  display_examples: False ]
# [  eval_batchsize: None ]
# [  evaltask: None ]
# [  load_from_checkpoint: False ]
# [  max_train_time: -1 ]
# [  num_epochs: 5.0 ]
# [  save_after_valid: False ]
# [  save_every_n_secs: -1 ]
# [  validation_cutoff: 1.0 ]
# [  validation_every_n_epochs: -1 ]
# [  validation_every_n_secs: -1 ]
# [  validation_max_exs: -1 ]
# [  validation_metric: accuracy ]
# [  validation_metric_mode: None ]
# [  validation_patience: 10 ]
# [  validation_share_agent: False ]
# [ Tensorboard Arguments: ]
# [  tensorboard_comment:  ]
# [  tensorboard_log: False ]
# [  tensorboard_metrics: None ]
# [  tensorboard_tag: None ]
# [ PytorchData Arguments: ]
# [  batch_length_range: 5 ]
# [  batch_sort_cache_type: pop ]
# [  batch_sort_field: text ]
# [  numworkers: 4 ]
# [  pytorch_context_length: -1 ]
# [  pytorch_datapath: None ]
# [  pytorch_include_labels: True ]
# [  pytorch_preprocess: False ]
# [  pytorch_teacher_batch_sort: False ]
# [  pytorch_teacher_dataset: None ]
# [  pytorch_teacher_task: None ]
# [  shuffle: False ]
# [ Dictionary Loop Arguments: ]
# [  dict_include_test: False ]
# [  dict_include_valid: False ]
# [  dict_maxexs: -1 ]
# [  log_every_n_secs: 2 ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ Seq2Seq Arguments: ]
# [  attention: none ]
# [  attention_length: 48 ]
# [  attention_time: post ]
# [  bidirectional: False ]
# [  decoder: shared ]
# [  dropout: 0.1 ]
# [  embeddingsize: 64 ]
# [  hiddensize: 64 ]
# [  input_dropout: 0.0 ]
# [  lookuptable: unique ]
# [  numlayers: 1 ]
# [  numsoftmax: 1 ]
# [  rnn_class: lstm ]
# [ Torch Generator Agent: ]
# [  beam_block_ngram: 0 ]
# [  beam_dot_log: False ]
# [  beam_min_length: 1 ]
# [  beam_min_n_best: 3 ]
# [  beam_size: 1 ]
# [  skip_generation: False ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: False ]
# [  betas: (0.9, 0.999) ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: random ]
# [  gpu: -1 ]
# [  gradient_clip: 0.1 ]
# [  history_size: -1 ]
# [  label_truncate: None ]
# [  learningrate: 1 ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  no_cuda: False ]
# [  nus: (0.7,) ]
# [  optimizer: sgd ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: False ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  update_freq: -1 ]
# [  use_reply: label ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: None ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# [ building dictionary first... ]
# [creating task(s): babi:task10k:1]
# [ running dictionary over data.. ]
# Building dictionary:   0% 0.00/9.00k [00:00<?, ?ex/s][loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# Building dictionary:  85% 7.62k/9.00k [00:00<00:00, 25.4kex/s][loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# Building dictionary: 100% 9.00k/9.00k [00:00<00:00, 25.5kex/s]
# Dictionary: saving dictionary to /tmp/babi_s2s.dict
# [ dictionary built with 26 tokens in 0s ]
# [ no model with opt yet at: /tmp/babi_s2s(.opt) ]
# Dictionary: loading dictionary from /tmp/babi_s2s.dict
# [ num words =  26 ]
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_train.txt]
# [ training... ]
# [ time:2.0s total_exs:640 epochs:0.07 time_left:152.0s ] {'exs': 640, 'lr': 1, 'num_updates': 20, 'loss': 30.45, 'token_acc': 0.5031, 'nll_loss': 1.523, 'ppl': 4.584}
# [ time:4.0s total_exs:1344 epochs:0.15 time_left:137.0s ] {'exs': 704, 'lr': 1, 'num_updates': 42, 'loss': 22.9, 'token_acc': 0.5845, 'nll_loss': 1.041, 'ppl': 2.831}
# [ time:6.0s total_exs:2016 epochs:0.22 time_left:134.0s ] {'exs': 672, 'lr': 1, 'num_updates': 63, 'loss': 21.51, 'token_acc': 0.5759, 'nll_loss': 1.024, 'ppl': 2.786}
# [ time:8.0s total_exs:2688 epochs:0.3 time_left:132.0s ] {'exs': 672, 'lr': 1, 'num_updates': 84, 'loss': 20.98, 'token_acc': 0.593, 'nll_loss': 0.9992, 'ppl': 2.716}
# [ time:10.0s total_exs:3360 epochs:0.37 time_left:131.0s ] {'exs': 672, 'lr': 1, 'num_updates': 105, 'loss': 20.7, 'token_acc': 0.5826, 'nll_loss': 0.9858, 'ppl': 2.68}
# [ time:12.0s total_exs:4064 epochs:0.45 time_left:127.0s ] {'exs': 704, 'lr': 1, 'num_updates': 127, 'loss': 21.86, 'token_acc': 0.5866, 'nll_loss': 0.9936, 'ppl': 2.701}
# [ time:14.0s total_exs:4736 epochs:0.53 time_left:124.0s ] {'exs': 672, 'lr': 1, 'num_updates': 148, 'loss': 20.33, 'token_acc': 0.593, 'nll_loss': 0.9682, 'ppl': 2.633}
# [ time:16.0s total_exs:5408 epochs:0.6 time_left:122.0s ] {'exs': 672, 'lr': 1, 'num_updates': 169, 'loss': 20.2, 'token_acc': 0.5751, 'nll_loss': 0.962, 'ppl': 2.617}
# [ time:18.0s total_exs:6048 epochs:0.67 time_left:121.0s ] {'exs': 640, 'lr': 1, 'num_updates': 189, 'loss': 19.23, 'token_acc': 0.5813, 'nll_loss': 0.9617, 'ppl': 2.616}
# [ time:20.0s total_exs:6720 epochs:0.75 time_left:119.0s ] {'exs': 672, 'lr': 1, 'num_updates': 210, 'loss': 20.16, 'token_acc': 0.5751, 'nll_loss': 0.9598, 'ppl': 2.611}
# [ time:22.0s total_exs:7360 epochs:0.82 time_left:117.0s ] {'exs': 640, 'lr': 1, 'num_updates': 230, 'loss': 19.21, 'token_acc': 0.5922, 'nll_loss': 0.9607, 'ppl': 2.614}
# [ time:24.0s total_exs:8064 epochs:0.9 time_left:114.0s ] {'exs': 704, 'lr': 1, 'num_updates': 252, 'loss': 21.04, 'token_acc': 0.5845, 'nll_loss': 0.9562, 'ppl': 2.602}
# [ time:26.0s total_exs:8736 epochs:0.97 time_left:112.0s ] {'exs': 672, 'lr': 1, 'num_updates': 273, 'loss': 19.8, 'token_acc': 0.5908, 'nll_loss': 0.9429, 'ppl': 2.568}
# [ time:28.0s total_exs:9408 epochs:1.05 time_left:110.0s ] {'exs': 672, 'lr': 1, 'num_updates': 294, 'loss': 19.85, 'token_acc': 0.5856, 'nll_loss': 0.9452, 'ppl': 2.573}
# [ time:31.0s total_exs:10080 epochs:1.12 time_left:108.0s ] {'exs': 672, 'lr': 1, 'num_updates': 315, 'loss': 19.71, 'token_acc': 0.5908, 'nll_loss': 0.9385, 'ppl': 2.556}
# [ time:33.0s total_exs:10784 epochs:1.2 time_left:106.0s ] {'exs': 704, 'lr': 1, 'num_updates': 337, 'loss': 20.41, 'token_acc': 0.6087, 'nll_loss': 0.9279, 'ppl': 2.529}
# [ time:35.0s total_exs:11456 epochs:1.27 time_left:104.0s ] {'exs': 672, 'lr': 1, 'num_updates': 358, 'loss': 19.2, 'token_acc': 0.6071, 'nll_loss': 0.9145, 'ppl': 2.495}
# [ time:37.0s total_exs:12096 epochs:1.34 time_left:102.0s ] {'exs': 640, 'lr': 1, 'num_updates': 378, 'loss': 17.54, 'token_acc': 0.632, 'nll_loss': 0.8768, 'ppl': 2.403}
# [ time:39.0s total_exs:12768 epochs:1.42 time_left:100.0s ] {'exs': 672, 'lr': 1, 'num_updates': 399, 'loss': 18.66, 'token_acc': 0.6324, 'nll_loss': 0.8886, 'ppl': 2.432}
# [ time:41.0s total_exs:13440 epochs:1.49 time_left:98.0s ] {'exs': 672, 'lr': 1, 'num_updates': 420, 'loss': 18.89, 'token_acc': 0.631, 'nll_loss': 0.8993, 'ppl': 2.458}
# [ time:43.0s total_exs:14080 epochs:1.56 time_left:96.0s ] {'exs': 640, 'lr': 1, 'num_updates': 440, 'loss': 17.02, 'token_acc': 0.657, 'nll_loss': 0.8508, 'ppl': 2.342}
# [ time:45.0s total_exs:14784 epochs:1.64 time_left:94.0s ] {'exs': 704, 'lr': 1, 'num_updates': 462, 'loss': 18.28, 'token_acc': 0.6712, 'nll_loss': 0.831, 'ppl': 2.296}
# [ time:47.0s total_exs:15456 epochs:1.72 time_left:91.0s ] {'exs': 672, 'lr': 1, 'num_updates': 483, 'loss': 18.15, 'token_acc': 0.657, 'nll_loss': 0.8644, 'ppl': 2.373}
# [ time:49.0s total_exs:16096 epochs:1.79 time_left:90.0s ] {'exs': 640, 'lr': 1, 'num_updates': 503, 'loss': 16.84, 'token_acc': 0.6797, 'nll_loss': 0.8418, 'ppl': 2.321}
# [ time:51.0s total_exs:16768 epochs:1.86 time_left:88.0s ] {'exs': 672, 'lr': 1, 'num_updates': 524, 'loss': 16.49, 'token_acc': 0.7083, 'nll_loss': 0.7851, 'ppl': 2.193}
# [ time:53.0s total_exs:17440 epochs:1.94 time_left:86.0s ] {'exs': 672, 'lr': 1, 'num_updates': 545, 'loss': 16.64, 'token_acc': 0.7068, 'nll_loss': 0.7926, 'ppl': 2.209}
# [ time:55.0s total_exs:18144 epochs:2.02 time_left:83.0s ] {'exs': 704, 'lr': 1, 'num_updates': 567, 'loss': 16.86, 'token_acc': 0.7266, 'nll_loss': 0.7662, 'ppl': 2.152}
# [ time:57.0s total_exs:18816 epochs:2.09 time_left:81.0s ] {'exs': 672, 'lr': 1, 'num_updates': 588, 'loss': 15.81, 'token_acc': 0.7314, 'nll_loss': 0.7528, 'ppl': 2.123}
# [ time:60.0s total_exs:19488 epochs:2.17 time_left:79.0s ] {'exs': 672, 'lr': 1, 'num_updates': 609, 'loss': 16.83, 'token_acc': 0.7121, 'nll_loss': 0.8013, 'ppl': 2.228}
# [ time:62.0s total_exs:20160 epochs:2.24 time_left:77.0s ] {'exs': 672, 'lr': 1, 'num_updates': 630, 'loss': 15.41, 'token_acc': 0.7396, 'nll_loss': 0.7336, 'ppl': 2.083}
# [ time:64.0s total_exs:20896 epochs:2.32 time_left:75.0s ] {'exs': 736, 'lr': 1, 'num_updates': 653, 'loss': 17.43, 'token_acc': 0.7242, 'nll_loss': 0.7579, 'ppl': 2.134}
# [ time:66.0s total_exs:21568 epochs:2.4 time_left:73.0s ] {'exs': 672, 'lr': 1, 'num_updates': 674, 'loss': 16.01, 'token_acc': 0.7277, 'nll_loss': 0.7623, 'ppl': 2.143}
# [ time:68.0s total_exs:22240 epochs:2.47 time_left:71.0s ] {'exs': 672, 'lr': 1, 'num_updates': 695, 'loss': 14.64, 'token_acc': 0.744, 'nll_loss': 0.6969, 'ppl': 2.008}
# [ time:70.0s total_exs:22944 epochs:2.55 time_left:68.0s ] {'exs': 704, 'lr': 1, 'num_updates': 717, 'loss': 15.96, 'token_acc': 0.733, 'nll_loss': 0.7255, 'ppl': 2.066}
# [ time:72.0s total_exs:23616 epochs:2.62 time_left:66.0s ] {'exs': 672, 'lr': 1, 'num_updates': 738, 'loss': 15.22, 'token_acc': 0.7195, 'nll_loss': 0.7246, 'ppl': 2.064}
# [ time:74.0s total_exs:24256 epochs:2.7 time_left:64.0s ] {'exs': 640, 'lr': 1, 'num_updates': 758, 'loss': 13.93, 'token_acc': 0.7359, 'nll_loss': 0.6967, 'ppl': 2.007}
# [ time:76.0s total_exs:24928 epochs:2.77 time_left:62.0s ] {'exs': 672, 'lr': 1, 'num_updates': 779, 'loss': 15.16, 'token_acc': 0.7284, 'nll_loss': 0.7219, 'ppl': 2.058}
# [ time:78.0s total_exs:25600 epochs:2.84 time_left:60.0s ] {'exs': 672, 'lr': 1, 'num_updates': 800, 'loss': 15.02, 'token_acc': 0.7195, 'nll_loss': 0.7152, 'ppl': 2.045}
# [ time:80.0s total_exs:26304 epochs:2.92 time_left:58.0s ] {'exs': 704, 'lr': 1, 'num_updates': 822, 'loss': 14.54, 'token_acc': 0.7621, 'nll_loss': 0.6609, 'ppl': 1.937}
# [ time:82.0s total_exs:26976 epochs:3.0 time_left:56.0s ] {'exs': 672, 'lr': 1, 'num_updates': 843, 'loss': 14.52, 'token_acc': 0.7366, 'nll_loss': 0.6916, 'ppl': 1.997}
# [ time:84.0s total_exs:27648 epochs:3.07 time_left:54.0s ] {'exs': 672, 'lr': 1, 'num_updates': 864, 'loss': 14.84, 'token_acc': 0.7411, 'nll_loss': 0.7066, 'ppl': 2.027}
# [ time:87.0s total_exs:28320 epochs:3.15 time_left:52.0s ] {'exs': 672, 'lr': 1, 'num_updates': 885, 'loss': 13.95, 'token_acc': 0.7515, 'nll_loss': 0.6641, 'ppl': 1.943}
# [ time:89.0s total_exs:29056 epochs:3.23 time_left:49.0s ] {'exs': 736, 'lr': 1, 'num_updates': 908, 'loss': 15.61, 'token_acc': 0.748, 'nll_loss': 0.6787, 'ppl': 1.971}
# [ time:91.0s total_exs:29728 epochs:3.3 time_left:47.0s ] {'exs': 672, 'lr': 1, 'num_updates': 929, 'loss': 14.5, 'token_acc': 0.744, 'nll_loss': 0.6903, 'ppl': 1.994}
# [ time:93.0s total_exs:30400 epochs:3.38 time_left:45.0s ] {'exs': 672, 'lr': 1, 'num_updates': 950, 'loss': 13.27, 'token_acc': 0.7671, 'nll_loss': 0.6319, 'ppl': 1.881}
# [ time:95.0s total_exs:31136 epochs:3.46 time_left:43.0s ] {'exs': 736, 'lr': 1, 'num_updates': 973, 'loss': 15.2, 'token_acc': 0.7514, 'nll_loss': 0.6607, 'ppl': 1.936}
# [ time:97.0s total_exs:31808 epochs:3.53 time_left:41.0s ] {'exs': 672, 'lr': 1, 'num_updates': 994, 'loss': 13.97, 'token_acc': 0.75, 'nll_loss': 0.6653, 'ppl': 1.945}
# [ time:99.0s total_exs:32480 epochs:3.61 time_left:39.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1015, 'loss': 14.07, 'token_acc': 0.7522, 'nll_loss': 0.67, 'ppl': 1.954}
# [ time:101.0s total_exs:33184 epochs:3.69 time_left:37.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1037, 'loss': 13.79, 'token_acc': 0.7614, 'nll_loss': 0.6269, 'ppl': 1.872}
# [ time:103.0s total_exs:33888 epochs:3.77 time_left:34.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1059, 'loss': 14.69, 'token_acc': 0.7536, 'nll_loss': 0.6678, 'ppl': 1.95}
# [ time:105.0s total_exs:34560 epochs:3.84 time_left:32.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1080, 'loss': 13.33, 'token_acc': 0.7634, 'nll_loss': 0.6348, 'ppl': 1.887}
# [ time:107.0s total_exs:35296 epochs:3.92 time_left:30.0s ] {'exs': 736, 'lr': 1, 'num_updates': 1103, 'loss': 14.89, 'token_acc': 0.7466, 'nll_loss': 0.6475, 'ppl': 1.911}
# [ time:109.0s total_exs:35968 epochs:4.0 time_left:28.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1124, 'loss': 14.11, 'token_acc': 0.7374, 'nll_loss': 0.6721, 'ppl': 1.958}
# [ time:112.0s total_exs:36640 epochs:4.07 time_left:26.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1145, 'loss': 13.49, 'token_acc': 0.7381, 'nll_loss': 0.6426, 'ppl': 1.901}
# [ time:114.0s total_exs:37376 epochs:4.15 time_left:24.0s ] {'exs': 736, 'lr': 1, 'num_updates': 1168, 'loss': 14.43, 'token_acc': 0.7534, 'nll_loss': 0.6272, 'ppl': 1.872}
# [ time:116.0s total_exs:38048 epochs:4.23 time_left:22.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1189, 'loss': 12.62, 'token_acc': 0.7686, 'nll_loss': 0.601, 'ppl': 1.824}
# [ time:118.0s total_exs:38720 epochs:4.3 time_left:20.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1210, 'loss': 13.03, 'token_acc': 0.7589, 'nll_loss': 0.6203, 'ppl': 1.86}
# [ time:120.0s total_exs:39424 epochs:4.38 time_left:18.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1232, 'loss': 13.67, 'token_acc': 0.7557, 'nll_loss': 0.6212, 'ppl': 1.861}
# [ time:122.0s total_exs:40128 epochs:4.46 time_left:15.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1254, 'loss': 14.33, 'token_acc': 0.7372, 'nll_loss': 0.6516, 'ppl': 1.919}
# [ time:124.0s total_exs:40800 epochs:4.53 time_left:13.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1275, 'loss': 14.22, 'token_acc': 0.7269, 'nll_loss': 0.6771, 'ppl': 1.968}
# [ time:126.0s total_exs:41504 epochs:4.61 time_left:11.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1297, 'loss': 13.87, 'token_acc': 0.7457, 'nll_loss': 0.6305, 'ppl': 1.879}
# [ time:128.0s total_exs:42208 epochs:4.69 time_left:9.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1319, 'loss': 14.27, 'token_acc': 0.7422, 'nll_loss': 0.6485, 'ppl': 1.913}
# [ time:130.0s total_exs:42880 epochs:4.76 time_left:7.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1340, 'loss': 13.78, 'token_acc': 0.7344, 'nll_loss': 0.6563, 'ppl': 1.928}
# [ time:132.0s total_exs:43584 epochs:4.84 time_left:5.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1362, 'loss': 13.67, 'token_acc': 0.7415, 'nll_loss': 0.6214, 'ppl': 1.862}
# [ time:135.0s total_exs:44288 epochs:4.92 time_left:3.0s ] {'exs': 704, 'lr': 1, 'num_updates': 1384, 'loss': 13.33, 'token_acc': 0.7607, 'nll_loss': 0.606, 'ppl': 1.833}
# [ time:137.0s total_exs:44960 epochs:5.0 time_left:1.0s ] {'exs': 672, 'lr': 1, 'num_updates': 1405, 'loss': 13.43, 'token_acc': 0.7463, 'nll_loss': 0.6396, 'ppl': 1.896}
# [ time:137.0s total_exs:45024 epochs:5.0 time_left:0s ] {'exs': 64, 'lr': 1, 'num_updates': 1407, 'loss': 1.121, 'token_acc': 0.7734, 'nll_loss': 0.5607, 'ppl': 1.752}
# [ num_epochs completed:5.0 time elapsed:137.3462417125702s ]
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_valid.txt]
# [ running eval: valid ]
# valid:{'exs': 1000, 'accuracy': 0.544, 'f1': 0.544, 'bleu': 5.44e-10, 'lr': 1, 'num_updates': 1407, 'loss': 19.75, 'token_acc': 0.772, 'nll_loss': 0.5595, 'ppl': 1.75}
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_test.txt]
# [ running eval: test ]
# test:{'exs': 1000, 'accuracy': 0.51, 'f1': 0.51, 'bleu': 5.1e-10, 'lr': 1, 'num_updates': 1407, 'loss': 20.37, 'token_acc': 0.755, 'nll_loss': 0.5915, 'ppl': 1.807}

# %%
# !python ~/ParlAI/examples/display_model.py --task babi:task10k:1 --model seq2seq --model-file /tmp/babi_s2s
# Out:
# [ optional arguments: ]
# [  display_ignore_fields:  ]
# [  num_examples: 10 ]
# [ Main ParlAI Arguments: ]
# [  batchsize: 1 ]
# [  datapath: /root/ParlAI/data ]
# [  datatype: valid ]
# [  download_path: /root/ParlAI/downloads ]
# [  hide_labels: False ]
# [  image_mode: raw ]
# [  multitask_weights: [1] ]
# [  numthreads: 1 ]
# [  show_advanced_args: False ]
# [  task: babi:task10k:1 ]
# [ ParlAI Model Arguments: ]
# [  dict_class: parlai.core.dict:DictionaryAgent ]
# [  init_model: None ]
# [  model: seq2seq ]
# [  model_file: /tmp/babi_s2s ]
# [ ParlAI Image Preprocessing Arguments: ]
# [  image_cropsize: 224 ]
# [  image_size: 256 ]
# [ Seq2Seq Arguments: ]
# [  attention: none ]
# [  attention_length: 48 ]
# [  attention_time: post ]
# [  bidirectional: False ]
# [  decoder: same ]
# [  dropout: 0.1 ]
# [  embeddingsize: 128 ]
# [  hiddensize: 128 ]
# [  input_dropout: 0.0 ]
# [  lookuptable: unique ]
# [  numlayers: 2 ]
# [  numsoftmax: 1 ]
# [  rnn_class: lstm ]
# [ Torch Generator Agent: ]
# [  beam_block_ngram: 0 ]
# [  beam_dot_log: False ]
# [  beam_min_length: 1 ]
# [  beam_min_n_best: 3 ]
# [  beam_size: 1 ]
# [  skip_generation: False ]
# [ TorchAgent Arguments: ]
# [  add_p1_after_newln: False ]
# [  betas: (0.9, 0.999) ]
# [  delimiter:
#  ]
# [  embedding_projection: random ]
# [  embedding_type: random ]
# [  gpu: -1 ]
# [  gradient_clip: 0.1 ]
# [  history_size: -1 ]
# [  label_truncate: None ]
# [  learningrate: 1 ]
# [  lr_scheduler: reduceonplateau ]
# [  lr_scheduler_decay: 0.5 ]
# [  lr_scheduler_patience: 3 ]
# [  momentum: 0 ]
# [  nesterov: True ]
# [  no_cuda: False ]
# [  nus: (0.7,) ]
# [  optimizer: sgd ]
# [  person_tokens: False ]
# [  rank_candidates: False ]
# [  split_lines: False ]
# [  text_truncate: None ]
# [  truncate: -1 ]
# [  update_freq: -1 ]
# [  use_reply: label ]
# [  warmup_rate: 0.0001 ]
# [  warmup_updates: -1 ]
# [ Dictionary Arguments: ]
# [  bpe_debug: False ]
# [  dict_endtoken: __end__ ]
# [  dict_file: None ]
# [  dict_initpath: None ]
# [  dict_language: english ]
# [  dict_lower: False ]
# [  dict_max_ngram_size: -1 ]
# [  dict_maxtokens: -1 ]
# [  dict_minfreq: 0 ]
# [  dict_nulltoken: __null__ ]
# [  dict_starttoken: __start__ ]
# [  dict_textfields: text,labels ]
# [  dict_tokenizer: re ]
# [  dict_unktoken: __unk__ ]
# Dictionary: loading dictionary from /tmp/babi_s2s.dict
# [ num words =  26 ]
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# [ Loading existing model params from /tmp/babi_s2s ]
# /root/ParlAI/parlai/core/torch_agent.py:727: UserWarning: LR scheduler is different from saved. Starting fresh!
#   warn_once("LR scheduler is different from saved. Starting fresh!")
# [creating task(s): babi:task10k:1]
# [loading fbdialog data:/root/ParlAI/data/bAbI/tasks_1-20_v1-2/en-valid-10k-nosf/qa1_valid.txt]
# [eval_labels_choice]: bathroom
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# [eval_labels: bathroom]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: bathroom
# ~~
# [eval_labels_choice]: bathroom
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# bathroom
# Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# [eval_labels: bathroom]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: hallway
# ~~
# [eval_labels_choice]: bathroom
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# bathroom
# Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# bathroom
# John went to the garden.
# John travelled to the office.
# Where is Sandra?
# [eval_labels: bathroom]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: office
# ~~
# [eval_labels_choice]: office
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# bathroom
# Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# bathroom
# John went to the garden.
# John travelled to the office.
# Where is Sandra?
# bathroom
# Daniel journeyed to the bedroom.
# Daniel travelled to the hallway.
# Where is John?
# [eval_labels: office]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: hallway
# ~~
# [eval_labels_choice]: hallway
# [babi:task10k:1]: Sandra travelled to the office.
# Sandra went to the bathroom.
# Where is Sandra?
# bathroom
# Mary went to the bedroom.
# Daniel moved to the hallway.
# Where is Sandra?
# bathroom
# John went to the garden.
# John travelled to the office.
# Where is Sandra?
# bathroom
# Daniel journeyed to the bedroom.
# Daniel travelled to the hallway.
# Where is John?
# office
# John went to the bedroom.
# John travelled to the office.
# Where is Daniel?
# [eval_labels: hallway]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: office
# - - - - - - - - - - - - - - - - - - - - -
# ~~
# [eval_labels_choice]: garden
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# [eval_labels: garden]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: bathroom
# ~~
# [eval_labels_choice]: office
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# garden
# Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# [eval_labels: office]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: office
# ~~
# [eval_labels_choice]: office
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# garden
# Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# office
# John went back to the hallway.
# John travelled to the office.
# Where is Sandra?
# [eval_labels: office]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: office
# ~~
# [eval_labels_choice]: office
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# garden
# Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# office
# John went back to the hallway.
# John travelled to the office.
# Where is Sandra?
# office
# Sandra journeyed to the hallway.
# Daniel moved to the office.
# Where is John?
# [eval_labels: office]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: office
# ~~
# [eval_labels_choice]: office
# [babi:task10k:1]: Sandra went back to the bathroom.
# Mary moved to the garden.
# Where is Mary?
# garden
# Mary went back to the hallway.
# Sandra went to the office.
# Where is Sandra?
# office
# John went back to the hallway.
# John travelled to the office.
# Where is Sandra?
# office
# Sandra journeyed to the hallway.
# Daniel moved to the office.
# Where is John?
# office
# Mary went to the office.
# Sandra went to the office.
# Where is John?
# [eval_labels: office]
# [label_candidates: office|bathroom|kitchen|hallway|bedroom|...and 1 more]
#    [Seq2Seq]: office
# - - - - - - - - - - - - - - - - - - - - -
# ~~

# %% [markdown]
# ### Ranking model: memory network
#
# We saw in the class that Memory Networks ([Sukhbaatar et al. 15'](https://papers.nips.cc/paper/5846-end-to-end-memory-networks.pdf)) rely on an explicit memory "database". this is especially adapted to tasks where a few useful memories are "hidden" among distractor memories.
# These type of networks worktherefore  especially well for the bAbI tasks by turning the previous dialog turns as memories and the question as the query.
# Here is an illustration of how a memory network work:
#
# ![Memory Network schema](https://raw.githubusercontent.com/louismartin/ammi-2019-bordes-DeepNLP/master/lab1/memory_network.png)
#
#
# ---
# **Question 4**
# - **4.d.** Explain how hops work in a memory network (either with words or formulas using the notations of the above figure)
# - **4.e.** How can a memory network be used to rank multiple candidates?
#   (*hint: you can look at the [implementation](https://github.com/facebookresearch/ParlAI/blob/6bd0e58692b3fd3a13b5f654944525ac1b7cd8e3/parlai/agents/memnn/modules.py#L22) of the memory network in ParlAI and especially the `_score()` method. Recall how the IR baseline worked.*)
#
# *ANSWER HERE*
#
#
# ---

# %% [markdown]
#     4d)-We use  a dot product to compute the similarity between the question vector and the memory vectors
#     -We then Apply a softmax to these simialrity scores to get probability and weights between 0 and 1
#     -We  use these newly-calculated weights to compute the weighted sum of the original memory vectors which gives
#     another input vector
#
#     4e)-we use dot product

# %% [markdown]
# - **4.f.** Using the ParlAI implementation, train a memory network on bAbI tasks 1, 2 and 3 (10k) and compare its results with the baselines.
#    (*hint: use a 1 thread, a batch size of 32 and 5 epochs*)

# %%
# SOLUTION
for i in range(3):
    print(f'~ Task {i+1} ~')
    # !python ~/ParlAI/examples/train_model.py -t babi:task10k:{i+1} -m memnn -mf /tmp/babi{i+1}_memnn -bs 32 -eps 5 | grep "'accuracy':"
# Out:
# ~ Task 1 ~
# Building dictionary: 100% 9.00k/9.00k [00:00<00:00, 24.7kex/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /root/ParlAI/parlai/core/torch_ranker_agent.py:376: UserWarning: [ Executing train mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:214: UserWarning: Some training metrics are omitted for speed. Set the flag `--train-predict` to calculate train metrics.
#   "Some training metrics are omitted for speed. Set the flag "
# /root/ParlAI/parlai/core/torch_ranker_agent.py:376: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# valid:{'exs': 1000, 'accuracy': 0.981, 'f1': 0.981, 'hits@1': 0.981, 'hits@5': 1.0, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 9.81e-10, 'lr': 1, 'num_updates': 1407, 'examples': 1000, 'loss': 49.73, 'mean_loss': 0.04973, 'mean_rank': 1.022}
# test:{'exs': 1000, 'accuracy': 0.981, 'f1': 0.981, 'hits@1': 0.981, 'hits@5': 1.0, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 9.81e-10, 'lr': 1, 'num_updates': 1407, 'examples': 1000, 'loss': 70.27, 'mean_loss': 0.07027, 'mean_rank': 1.02}
# ~ Task 2 ~
# Building dictionary: 100% 9.00k/9.00k [00:00<00:00, 18.5kex/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /root/ParlAI/parlai/core/torch_ranker_agent.py:376: UserWarning: [ Executing train mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:214: UserWarning: Some training metrics are omitted for speed. Set the flag `--train-predict` to calculate train metrics.
#   "Some training metrics are omitted for speed. Set the flag "
# /root/ParlAI/parlai/core/torch_ranker_agent.py:376: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# valid:{'exs': 1000, 'accuracy': 0.184, 'f1': 0.184, 'hits@1': 0.184, 'hits@5': 0.851, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 1.84e-10, 'lr': 1, 'num_updates': 1407, 'examples': 1000, 'loss': 2340.0, 'mean_loss': 2.34, 'mean_rank': 3.416}
# test:{'exs': 1000, 'accuracy': 0.209, 'f1': 0.209, 'hits@1': 0.209, 'hits@5': 0.844, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 2.09e-10, 'lr': 1, 'num_updates': 1407, 'examples': 1000, 'loss': 2244.0, 'mean_loss': 2.244, 'mean_rank': 3.332}
# ~ Task 3 ~
# Building dictionary: 100% 9.00k/9.00k [00:01<00:00, 8.26kex/s]
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /root/ParlAI/parlai/core/torch_ranker_agent.py:376: UserWarning: [ Executing train mode with provided inline set of candidates ]
#   ''.format(mode)
# /root/ParlAI/parlai/core/torch_ranker_agent.py:214: UserWarning: Some training metrics are omitted for speed. Set the flag `--train-predict` to calculate train metrics.
#   "Some training metrics are omitted for speed. Set the flag "
# /root/ParlAI/parlai/core/torch_ranker_agent.py:376: UserWarning: [ Executing eval mode with provided inline set of candidates ]
#   ''.format(mode)
# valid:{'exs': 1000, 'accuracy': 0.352, 'f1': 0.352, 'hits@1': 0.352, 'hits@5': 0.979, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 3.52e-10, 'lr': 1, 'num_updates': 1407, 'examples': 1000, 'loss': 1744.0, 'mean_loss': 1.744, 'mean_rank': 2.557}
# test:{'exs': 1000, 'accuracy': 0.368, 'f1': 0.368, 'hits@1': 0.368, 'hits@5': 0.985, 'hits@10': 1.0, 'hits@100': 1.0, 'bleu': 3.68e-10, 'lr': 1, 'num_updates': 1407, 'examples': 1000, 'loss': 1653.0, 'mean_loss': 1.653, 'mean_rank': 2.509}

# %% [markdown]
# ## 5. To go further

# %% [markdown]
# If you want to go further you can try to do the following:
#
# - Retrieve and plot the attention of the memory network for the different hops along the memories.
# - For the seq2seq model, can you plot the training loss? The validation loss? Both on the same plot?
# - Can you show an example of overfitting?
# - Adapt the seq2seq model for ranking using the [torch ranker tutorial](http://www.parl.ai/static/docs/tutorial_torch_ranker_agent.html)
# - Try multitasking babi and squad, does it improve the performance? (this will require more GPU power than what is available in google colab)
# - You can play around with other models and other tasks
# - Try interfacing ParlAI with [messenger](http://www.parl.ai/static/docs/tutorial_messenger.html )
